# %%
import pandas as pd
import numpy as np
import nltk
import string
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

# %%
# Load training data
file_path = 'data/training-Obama-Romney-tweets.xlsx'

# Load Obama tweets
obama_df = pd.read_excel(file_path, sheet_name="Obama")

# Load Romney tweets
romney_df = pd.read_excel(file_path, sheet_name="Romney")

# %%
# Display the first few rows of Obama dataset to check the data
print("Obama Tweets:")
print(obama_df.head())
print("No of obama tweets : ", len(obama_df))
# Out:
# Obama Tweets:
#    Unnamed: 0                 date            time  \
# 0         NaN  2012-10-16 00:00:00  10:28:53-05:00
# 1         NaN  2016-12-10 00:00:00  10:09:00-05:00
# 2         NaN  2012-10-16 00:00:00  10:04:30-05:00
# 3         NaN  2012-10-16 00:00:00  10:00:36-05:00
# 4         NaN  2012-10-16 00:00:00  09:50:08-05:00
#
#                                      Anootated tweet Class  Your class label
# 0  Kirkpatrick, who wore a baseball cap embroider...     0               NaN
# 1  Question: If <e>Romney</e> and <e>Obama</e> ha...     2               NaN
# 2  #<e>obama</e> debates that Cracker Ass Cracker...     1               NaN
# 3  RT @davewiner Slate: Blame <e>Obama</e> for fo...     2               NaN
# 4  @Hollivan @hereistheanswer  Youre missing the ...     0               NaN
# No of obama tweets :  7198

# %%
# Display the first few rows of Romney dataset to check the data
print("\nRomney Tweets:")
print(romney_df.head())
print("No of Romaney tweets : ", len(romney_df))
# Out:
# Romney Tweets:
#    Unnamed: 0                 date            time  \
# 0         NaN  2012-10-16 00:00:00  09:38:08-05:00
# 1         NaN  2012-10-16 00:00:00  10:22:34-05:00
# 2         NaN  2012-10-16 00:00:00  10:14:18-05:00
# 3         NaN  2012-10-16 00:00:00  09:27:16-05:00
# 4         NaN  2012-10-16 00:00:00  10:11:43-05:00
#
#                                      Anootated tweet Class  Your class label
# 0  Insidious!<e>Mitt Romney</e>'s Bain Helped Phi...    -1               NaN
# 1  Senior <e>Romney</e> Advisor Claims <e>Obama</...     2               NaN
# 2  .@WardBrenda @shortwave8669 @allanbourdius you...    -1               NaN
# 3  <e>Mitt Romney</e> still doesn't <a>believe</a...    -1               NaN
# 4  <e>Romney</e>'s <a>tax plan</a> deserves a 2nd...    -1               NaN
# No of Romaney tweets :  7200

# %%
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/dheerajkumarbuchala/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/dheerajkumarbuchala/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/dheerajkumarbuchala/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
valid_classes = [-1, 0, 1]

# %%
# Pre-Processing the Obama DataFrame created
obama_df = obama_df[obama_df['Class'].isin(valid_classes)]
print("No of obama tweets after cleaning : ", len(obama_df))
# Out:
# No of obama tweets after cleaning :  5471

# %%
# Pre-Processing the Romney DataFrame created
romney_df = romney_df[romney_df['Class'].isin(valid_classes)]
print("No of romney tweets after cleaning : ", len(romney_df))
# Out:
# No of romney tweets after cleaning :  5648

# %%
obama_anootated_tweets = obama_df['Anootated tweet']
obama_assigned_class = obama_df['Class']

romney_anootated_tweets = romney_df['Anootated tweet']
romney_assigned_class = romney_df['Class']

# %%
obama_anootated_tweets = obama_anootated_tweets.tolist()
obama_assigned_class = obama_assigned_class.tolist()

romney_anootated_tweets = romney_anootated_tweets.tolist()
romney_assigned_class = romney_assigned_class.tolist()

# %%
def dataClean(tweets):
    cleaned_tweets = list()
    for tweet in tweets:
        tweet = str(tweet).encode('ascii', 'ignore').strip()
        tweet = str(tweet)
        textCleaner = re.compile('(</?[a-zA-Z]+>|https?:\/\/[^\s]*|(^|\s)RT(\s|$)|@[^\s]+|\d+)')
        cleanedTweet = re.sub(textCleaner, ' ', tweet)
        cleanedTweet = re.sub('(?<=^|(?<=[^a-zA-Z0-9-_\.]))@([A-Za-z]+[A-Za-z0-9]+)',' ',cleanedTweet)
        cleanedTweet = re.sub('[^\sa-zA-Z]+','',cleanedTweet)
        cleanedTweet = re.sub('\s+',' ',cleanedTweet)
        cleanedTweet = cleanedTweet[1:].strip()
        cleaned_tweets.append(cleanedTweet)
    return cleaned_tweets

# %%
obama_cleaned_tweets = dataClean(obama_anootated_tweets)
romney_cleaned_tweets = dataClean(romney_anootated_tweets)

# %%
print(obama_cleaned_tweets)
# Out:
# ['Kirkpatrick who wore a baseball cap embroidered with Barack Obamas signature and had the hangdog look of Jason segel Courier Journal', 'obama debates that Cracker Ass Cracker tonight I will be tuned in TeamObama', 'Youre missing the point Im afraid you do not understand the bigger picture if you dont care if Obama re elected', 'I was raised as a Democrat left the party years ago but in my lifetime I have never seen a president divide the country like obama', 'The Obama camp cant afford to lower expectations for tonights debate The President MUST give a strong performance', 'Obama pot policy disappointing to say the least legaizeit via', 'Not all of Hollywood has his back Gene Simmons Yanks Obama Support Calls Him a PissPoor President', 'Obama s Expedient Speak fair in order to Slenderizing BiscuitTaiwan Tensions GjN', 'I had a dream that i was smoking with Obama oO', 'The Washington Times The Presidents Popularity Bubble Has Burst Barack Obama Fox Nation Obama OFA tcot', 'Obama s priorities K for gaydar research not security for our embassy in Libya tlot tcot p', 'United states of Islam Does Obama really think that Weirdoooooo', 'they created this debt now plame Obama handing out money to billionaires and two wars u braked u owned', 'Obama has not kept ONE of his promises of the town hall debates Why believe him tonight', 'This sub is here talking shit about Obama', 'obama ist tot', 'when you go against your own ideas to hurt Obama and America for electing a blk pres Youve shown your whole hand dumbass', 'Still my Idol Mr President Obama', 'Pretty creepy No wonder Obama always has Starbursts in his pocket Some equally realistic theories here', 'Just saw a truck with a NASA sticker and an Obama sticker New BFF', 'debate tonight I hope Obama brings a lot of energy tonight This debate is crucial obama', 'you said so much good things about Obama when the small business owner picked him up', 'Hillary taken the spaken for Obama s ignorance Attaboy Obama The more blind people
Brilliant p tlot tcot', 'Mitt Romney always worshiped his father This must hurt at least a little', 'Hope the debate goes as well for Romney tonight as it did the first time around But with hair like that how could it not', 'Fuck mitt romney Rick Ross voice', 'romney can kiss my ass', 'Yet Another CEO Asks Employees to Vote Romney for Yet Another CEO Asks Employees to Vote Romney for Sake of th', 'Radio Ad mitt Romney completely wrong via', 'If youre a woman voting for Romney you either have a penis an IQ of or are close minded as hell responsestoMonicaCrowley', 'good one DNC but more importantly Romney didnt think to snatch up this domain', 'If I were the Yankees Id send Arod to debate Romney amp start Barack Obama at rd base Hey its not like either of them can get any worse', 'If BO comes out fighting Mitt will simply take advantage of the obvious pressure on the president', 'Romney isnt clueless Hes evil', 'Romney could his make his second fortune in teaching other people how to lie as effortlessly as he does', 'SHOCKER Romney jobs plan revealed to be flimflam p p b democrat Hofstra', 'where are these polls showing Romney ahead I never see them', 'BOOM Former Romney senior aide says Romney will say and do anything to close a deal', 'FOX News is really struggling to defend Romney amp Ryan Oh amp who is this chick Did she really say that on National TV', 'Oh yeah Romney I pray to baby Jesus you assault Obama with an AK tonight God Bless', 'can u tell which candidate you support Romney i hope', 'Romney picking up steam now has of black vote atleastitsnot', 'Patton Oswalt Gives Romney Debate Tips On Conan VIDEO', 'Ann might try a mirror Ann Romney blames media negative ads for husbands image stopit thisishard romneyshambles', 'Dear misinformed public Romney does not only propose some minor tax cuts but major cutting of government spending RomneyRyan', 'Mitt Romney s jobs plan math is as bogus as his tax plan math', 'reported Mitt Romney s sponsored shit as spam on facebook', 'snoop doggs reasons not to vote for romney this muthafuckas name is mitt hes a morman but he aint got no hoes', 'George Bush said Mitt Romney will be a great president are people really respecting his opinion', 'Romney may have been in othe ...

# %%
def tokenizationAndLemmatization(tweets):
    cleaned_tweets = list()
    for tweet in tweets:
        tweet = tweet.lower()
        tokens = word_tokenize(tweet)
        stop_words = set(stopwords.words('english'))
        tokens = [word for word in tokens if word not in stop_words]
    
        # Lemmatization
        lemmatizer = WordNetLemmatizer()
        tokens = [lemmatizer.lemmatize(word) for word in tokens]
    
        # Rejoin tokens into a cleaned tweet
        cleaned_tweet = ' '.join(tokens)
    
        cleaned_tweets.append(cleaned_tweet)
    return cleaned_tweets

# %%
obama_cleaned_tweets = tokenizationAndLemmatization(obama_cleaned_tweets)
romney_cleaned_tweets = tokenizationAndLemmatization(romney_cleaned_tweets)

# %%
print(obama_cleaned_tweets)
# Out:
