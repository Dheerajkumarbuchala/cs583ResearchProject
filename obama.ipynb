# %%
import pandas as pd
import numpy as np
import nltk
import string
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

# %%
import import_ipynb
import textPreprocessing
# Out:
# importing Jupyter notebook from textPreprocessing.ipynb
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/dheerajkumarbuchala/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/dheerajkumarbuchala/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/dheerajkumarbuchala/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# Load training data
file_path = 'data/training-Obama-Romney-tweets.xlsx'

# Load Obama tweets
obama_df = pd.read_excel(file_path, sheet_name="Obama")

# %%
# Display the first few rows of Obama dataset to check the data
print("Obama Tweets:")
print(obama_df.head())
print("No of obama tweets : ", len(obama_df))
# Out:
# Obama Tweets:
#    Unnamed: 0                 date            time  \
# 0         NaN  2012-10-16 00:00:00  10:28:53-05:00
# 1         NaN  2016-12-10 00:00:00  10:09:00-05:00
# 2         NaN  2012-10-16 00:00:00  10:04:30-05:00
# 3         NaN  2012-10-16 00:00:00  10:00:36-05:00
# 4         NaN  2012-10-16 00:00:00  09:50:08-05:00
#
#                                      Anootated tweet Class  Your class label
# 0  Kirkpatrick, who wore a baseball cap embroider...     0               NaN
# 1  Question: If <e>Romney</e> and <e>Obama</e> ha...     2               NaN
# 2  #<e>obama</e> debates that Cracker Ass Cracker...     1               NaN
# 3  RT @davewiner Slate: Blame <e>Obama</e> for fo...     2               NaN
# 4  @Hollivan @hereistheanswer  Youre missing the ...     0               NaN
# No of obama tweets :  7198

# %%
valid_classes = [-1, 0, 1]

# %%
# Pre-Processing the Obama DataFrame created
obama_df = obama_df[obama_df['Class'].isin(valid_classes)]
print("No of obama tweets after cleaning : ", len(obama_df))
# Out:
# No of obama tweets after cleaning :  5471

# %%
obama_anootated_tweets = obama_df['Anootated tweet']
obama_assigned_class = obama_df['Class']

# %%
obama_anootated_tweets = obama_anootated_tweets.tolist()
obama_assigned_class = obama_assigned_class.tolist()

# %%
obama_cleaned_tweets = textPreprocessing.dataClean(obama_anootated_tweets)
print(obama_cleaned_tweets)
# Out:
# ['Kirkpatrick who wore a baseball cap embroidered with Barack Obamas signature and had the hangdog look of Jason segel Courier Journal', 'obama debates that Cracker Ass Cracker tonight I will be tuned in TeamObama', 'Youre missing the point Im afraid you do not understand the bigger picture if you dont care if Obama re elected', 'I was raised as a Democrat left the party years ago but in my lifetime I have never seen a president divide the country like obama', 'The Obama camp cant afford to lower expectations for tonights debate The President MUST give a strong performance', 'Obama pot policy disappointing to say the least legaizeit via', 'Not all of Hollywood has his back Gene Simmons Yanks Obama Support Calls Him a PissPoor President', 'Obama s Expedient Speak fair in order to Slenderizing BiscuitTaiwan Tensions GjN', 'I had a dream that i was smoking with Obama oO', 'The Washington Times The Presidents Popularity Bubble Has Burst Barack Obama Fox Nation Obama OFA tcot', 'Obama s priorities K for gaydar research not security for our embassy in Libya tlot tcot p', 'United states of Islam Does Obama really think that Weirdoooooo', 'they created this debt now plame Obama handing out money to billionaires and two wars u braked u owned', 'Obama has not kept ONE of his promises of the town hall debates Why believe him tonight', 'This sub is here talking shit about Obama', 'obama ist tot', 'when you go against your own ideas to hurt Obama and America for electing a blk pres Youve shown your whole hand dumbass', 'Still my Idol Mr President Obama', 'Pretty creepy No wonder Obama always has Starbursts in his pocket Some equally realistic theories here', 'Just saw a truck with a NASA sticker and an Obama sticker New BFF', 'debate tonight I hope Obama brings a lot of energy tonight This debate is crucial obama', 'you said so much good things about Obama when the small business owner picked him up', 'Hillary taken the spaken for Obama s ignorance Attaboy Obama The more blind people that have ur back the better off u will be Spineless', 'Im a South African and i say Obama is the best thing to happen to America', 'RT Smart women know when Obama said his policies would cause energy prices to skyrocket he meant it tcot SGP', 'Tonight Obama will be focused and forceful Leaving voters to wonder why he didnt know he should do that in the first debate', 'Obama may need ground game of his backers are following elex very closely compared with in', 'i remember when Obama first got elected niggas acted like it was the second coming of Jesus', 'Obama is working out next to me', 'Pretty much If Obama loses tonight expect the madness meltdown to breach containment', 'If Obama wins I wanna move to New York', 'Just once I want to hear Obama say Nigga please yeees', 'Barack Obama quietly gives himself control of all communication systems in America NOTObama ObamaVSAmerica', 'last kid voted Johnson but he would bk OBAMA how does that make sense Oh my god I could scream', 'thanksgiving obama turkey on google omg thats so wrong', 'Okay Obama It is time to put your game face on and get shit done', 'Im actually beginning to feel sorry for Obama never mind it passed Like smelly gas', 'I agree we cant afford more years of Obama', 'I feel you but thee next indie pres we will use this time next term after obm I fuck wt obama but the ent world should step to him', 'Has anyone seen obama Oh hes hiding behind Hillary epicfail Hillary will never see her fantasy of being potus weak', 'CDN news Muppets Denounce Democrats Call Obama a Puppet Ahead of the Democratorganized conservative tcot', 'New W intelligence Syrian rebels dont have the numbers to win Obama doesnt either Debka Obamassad', 'RT Gov Gary Johnson pulling votes from waste your vote Obama must go', 'Bob Beckel Obama created mil jobs so there where mil people without jobs in January are you kidding me Bob', 'Obama s sustained efforts to claim hes not responsible for anything belong in a letter of resignation  ...

# %%
obama_cleaned_tweets = textPreprocessing.tokenizationAndLemmatization(obama_cleaned_tweets)
print(obama_cleaned_tweets)
# Out:
# ['kirkpatrick wore baseball cap embroidered barack obamas signature hangdog look jason segel courier journal', 'obama debate cracker as cracker tonight tuned teamobama', 'youre missing point im afraid understand bigger picture dont care obama elected', 'raised democrat left party year ago lifetime never seen president divide country like obama', 'obama camp cant afford lower expectation tonight debate president must give strong performance', 'obama pot policy disappointing say least legaizeit via', 'hollywood back gene simmons yank obama support call pisspoor president', 'obama expedient speak fair order slenderizing biscuittaiwan tension gjn', 'dream smoking obama oo', 'washington time president popularity bubble burst barack obama fox nation obama ofa tcot', 'obama priority k gaydar research security embassy libya tlot tcot p', 'united state islam obama really think weirdoooooo', 'created debt plame obama handing money billionaire two war u braked u owned', 'obama kept one promise town hall debate believe tonight', 'sub talking shit obama', 'obama ist tot', 'go idea hurt obama america electing blk pres youve shown whole hand dumbass', 'still idol mr president obama', 'pretty creepy wonder obama always starbursts pocket equally realistic theory', 'saw truck nasa sticker obama sticker new bff', 'debate tonight hope obama brings lot energy tonight debate crucial obama', 'said much good thing obama small business owner picked', 'hillary taken spaken obama ignorance attaboy obama blind people ur back better u spineless', 'im south african say obama best thing happen america', 'rt smart woman know obama said policy would cause energy price skyrocket meant tcot sgp', 'tonight obama focused forceful leaving voter wonder didnt know first debate', 'obama may need ground game backer following elex closely compared', 'remember obama first got elected nigga acted like second coming jesus', 'obama working next', 'pretty much obama loses tonight expect madness meltdown breach containment', 'obama win wan na move new york', 'want hear obama say nigga please yeees', 'barack obama quietly give control communication system america notobama obamavsamerica', 'last kid voted johnson would bk obama make sense oh god could scream', 'thanksgiving obama turkey google omg thats wrong', 'okay obama time put game face get shit done', 'im actually beginning feel sorry obama never mind passed like smelly gas', 'agree cant afford year obama', 'feel thee next indie pres use time next term obm fuck wt obama ent world step', 'anyone seen obama oh he hiding behind hillary epicfail hillary never see fantasy potus weak', 'cdn news muppets denounce democrat call obama puppet ahead democratorganized conservative tcot', 'new w intelligence syrian rebel dont number win obama doesnt either debka obamassad', 'rt gov gary johnson pulling vote waste vote obama must go', 'bob beckel obama created mil job mil people without job january kidding bob', 'obama sustained effort claim he responsible anything belong letter resignation reelection campaign', 'reporter aware michelle voted yesterday obama thank goodness', 'obama debate around corner gaf security crazy', 'obama reminds kid one ego', 'obama walked short debate prep session morning adviser anita dunn david plouffe told reporter he feeling fabulous', 'look like obama may need two good debate assure victory', 'ya go romney lover whats crazy idea evil towards woman fucking stand right', 'liberal depressed obama debate tough bcuz u lock urself garage w running priusnothing happens b maher', 'vote obama', 'obama wont make eye contact debatepredictions', 'obama dont win gon na lotta sin lack money root evil inspire insta', 'townhallquestions mr obama someone else help brother kenya many others yur job', 'join supporting support president obama agenda via', 'president obama need understand win second term n white house u cant b nice republican anymore', 'japan set become biggest foreign creditor think forgot u nuking obama g ...
